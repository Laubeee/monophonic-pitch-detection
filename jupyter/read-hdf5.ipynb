# %%
import numpy as np
import h5py

# %%
f1 = h5py.File(r'C:\Users\Silvan\Desktop\any dataset johnglover\onsets.hdf5', 'r')
f1
# Out:
# <HDF5 file "onsets.hdf5" (mode r)>

# %%
list(f1.keys())
# Out:
# ['bass-elec-C-lo.wav',
#  'bass-elec2-E-lick.wav',
#  'bell-octave0.wav',
#  'bell-octave1.wav',
#  'bell-octave2.wav',
#  'child-imitate-owl.wav',
#  'child-imitate-shaker-hi-up.wav',
#  'clarinet-C-octave0-vib.wav',
#  'clarinet-C-octave0.wav',
#  'conga-muffled-1.wav',
#  'conga-open-1.wav',
#  'cymbal-hihat-foot-open.wav',
#  'cymbal-hihat-lick.wav',
#  'cymbal-hihat-openclose-stick.wav',
#  'cymbal-splash-stick.wav',
#  'drum-bass-hi-1.wav',
#  'drum-snare-drag.wav',
#  'drum-snare-roll-short.wav',
#  'drum-surdo-large-lick.wav',
#  'female-glissdown.wav',
#  'femalevoices_aa2_A3.wav',
#  'femalevoices_oo2_C#4.wav',
#  'flugel-C.wav',
#  'flugel-lick.wav',
#  'flute-alto-C.wav',
#  'flute-alto-lick.wav',
#  'glitch_groove_7.wav',
#  'guitar-ac-E-octave1.wav',
#  'guitar-classical-E-octave1-vib.wav',
#  'guitar-classical-lick.wav',
#  'guitar-elec-hollow-lick.wav',
#  'guitar-elec-solid-dist-E-octave1-long.wav',
#  'guitar-elec-solid-dist-EBfifths-octave1-long.wav',
# ...

# %%
f1['piano-studio-octave1.wav']
# Out:
# <HDF5 dataset "piano-studio-octave1.wav": shape (62450,), type "<f4">

# %%
f1['twangs_1.wav'][()]
# Out:
# array([ 0.        ,  0.00469971,  0.00991821, ..., -0.00326538,
#        -0.00292969, -0.00262451], dtype=float32)

# %%
import IPython.display as ipd
ipd.Audio(f1['twangs_1.wav'][()], rate=44100) # load a wav array
# ipd.Audio('audio/conga_groove.wav') # load a local WAV file
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for k in list(f1.keys()):
    ipd.Audio(f1[k][()], rate=44100)
